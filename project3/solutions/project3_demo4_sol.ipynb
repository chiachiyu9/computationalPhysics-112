# %% [markdown]
# # Poisson's equation

# %% [markdown]
# Now extend your solver to solve for Poisson's equation.
# * Consider a 64 x 64 grids in a domain ($-1<x<1$ and $-1<y<1$)
# * Assume $\rho(r)= \exp(-10r)$
# * Assume $u$ is zero on the four boundaries.
# * Solver for the potential $u$.
# * What is the corresponding electrical (or gravitational) field? (Hints: use `numpy.gradient()`)

# %%
import numpy as np
from scipy.sparse import dia_array  # if dia_array is not able, use dia_matrix
from scipy.sparse import dia_matrix
from scipy.sparse import csc_matrix
import scipy.sparse.linalg as splinalg
from numba import jit, njit, prange
import matplotlib.pyplot as plt

# %%
# Copy your Laplace's Equation solver from demo1 here
def generate_1_4_1_dia(usize=4):
    ex = np.ones(usize)
    data = np.array([-ex, 4 * ex, -ex])
    offsets = np.array([-1, 0, 1])
    A = dia_array((data, offsets), shape=(usize, usize)).toarray()
    return A

def generate_the_laplace_matrix_with_size(N=4):
    """
    assume sqrt(N) is an integer.

    """
    nsq = N*N
    A   = np.zeros((nsq,nsq))
    u   = generate_1_4_1_dia(N)

    d_matrix = generate_1_4_1_dia(N)
    o_matrix = -np.identity(N)
    z_matrix = np.zeros((N,N))

    init_matrix_kernel(N,A,u,d_matrix,o_matrix,z_matrix)
    return A

@njit(parallel=True)
def init_matrix_kernel(N,A,u,d_matrix,o_matrix, z_matrix):
    for i in prange(N):
        for j in prange(N):
            if u[i,j] == 4:
                # the elemen is another 1_4_1 matrix
                suba = d_matrix
            elif u[i,j] == -1:
                suba = o_matrix
            else:
                suba = z_matrix
            
            for i2 in range(N):
                for j2 in range(N):
                    ii = i2 + i*N
                    jj = j2 + j*N
                    A[ii,jj] = suba[i2,j2]
    return A

#def generate_the_rhs_vector_with_size(N=4):
#    b = np.zeros(N*N)
#    b[-N:] = 1
#    return b

def convert_solution(x):
    usize = np.sqrt(len(x))
    u = x.reshape(int(usize),int(usize)).transpose()
    return u

# %% [markdown]
# The right hand side vector need to be updated when there is a density field $\rho$.
# First, we write a function `generate_rho()` to generate the $N \times N$ density field.

# %%
def generate_rho(N, xmin=-1, xmax=1, ymin=-1,ymax=1):
    dx = (xmax-xmin)/N
    dy = (ymax-ymin)/N
    x = np.linspace(xmin+dx,xmax-dx,N)
    y = np.linspace(ymin+dy,ymax-dy,N)
    xx, yy = np.meshgrid(x,y,indexing="ij")
    radius = np.sqrt(xx**2 + yy**2)
    rho    = np.exp(-10*radius)
    return rho

# %%
# Visualize the density field
rho = generate_rho(N=64)
plt.imshow(rho)

# %% [markdown]
# Once we have the density filed, we need to modify the `generate_the_rhs_vector_with_size()` to include the density field.

# %%
def generate_the_rhs_vector_with_size(N=4, rho=None, dx=1):
    if rho is None:
        b = np.zeros(N*N)
        b[-N:] += 1
    else:
        b = rho.flatten() 
        b = -b*dx**2
    return b

# %% [markdown]
# We could solve the system by the same way in `solve_laplace()`.

# %%
def solve_laplace(N=16):
    A = generate_the_laplace_matrix_with_size(N=N)

    rho = generate_rho(N=N)
    b = generate_the_rhs_vector_with_size(N=N, rho=rho, dx=2/(N-1))
    #x = linalg.solve(A,b) # use scipy
    #x = lu_solve(A,b)      # use our solver
    x = splinalg.spsolve(A,b) # use scipy sparse solver
    u = convert_solution(x)
    return u

# %%
u = solve_laplace(N=64)
# Out:
# C:\Users\jocyl\AppData\Local\Temp\ipykernel_25732\3917867856.py:8: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   x = splinalg.spsolve(A,b) # use scipy sparse solver

# %%
# Visualize the solution
plt.imshow(u)
plt.colorbar()
plt.contour(u,colors="w")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       2 plt.imshow(u)
#       3 plt.colorbar()
# ----> 4 plt.contour(u,colors="Reds")
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\pyplot.py:2927, in contour(data, *args, **kwargs)
#    2925 @_copy_docstring_and_deprecators(Axes.contour)
#    2926 def contour(*args, data=None, **kwargs) -> QuadContourSet:
# -> 2927     __ret = gca().contour(
#    2928         *args, **({"data": data} if data is not None else {}), **kwargs
#    2929     )
#    2930     if __ret._A is not None:  # type: ignore[attr-defined]
#    2931         sci(__ret)
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\axes\_axes.py:6512, in Axes.contour(self, *args, **kwargs)
#    6503 """
#    6504 Plot contour lines.
#    6505
#    (...)
#    6509 %(contour_doc)s
#    6510 """
#    6511 kwargs['filled'] = False
# -> 6512 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6513 self._request_autoscale_view()
#    6514 return contours
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\contour.py:887, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     884 self.labelTexts = []
#     885 self.labelCValues = []
# --> 887 self.set_cmap(cmap)
#     888 if norm is not None:
#     889     self.set_norm(norm)
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\cm.py:602, in ScalarMappable.set_cmap(self, cmap)
#     600 self.cmap = _ensure_cmap(cmap)
#     601 if not in_init:
# --> 602     self.changed()
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\contour.py:1145, in ContourSet.changed(self)
#    1143 def changed(self):
#    1144     if not hasattr(self, "cvalues"):
# -> 1145         self._process_colors()  # Sets cvalues.
#    1146     # Force an autoscale immediately because self.to_rgba() calls
#    1147     # autoscale_None() internally with the data passed to it,
#    1148     # so if vmin/vmax are not set yet, this would override them with
#    1149     # content from *cvalues* rather than levels like we want
#    1150     self.norm.autoscale_None(self.levels)
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\contour.py:1299, in ContourSet._process_colors(self)
#    1297             i1 += 1
#    1298     self.cvalues = list(range(i0, i1))
# -> 1299     self.set_norm(mcolors.NoNorm())
#    1300 else:
#    1301     self.cvalues = self.layers
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\cm.py:651, in ScalarMappable.set_norm(self, norm)
#     637 def set_norm(self, norm):
#     638     """
#     639     Set the normalization instance.
#     640
#    (...)
#     649     on the colorbar to default.
#     650     """
# --> 651     self.norm = norm
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\cm.py:635, in ScalarMappable.norm(self, norm)
#     632 self._id_norm = self.norm.callbacks.connect('changed',
#     633                                             self.changed)
#     634 if not in_init:
# --> 635     self.changed()
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\contour.py:1150, in ContourSet.changed(self)
#    1145     self._process_colors()  # Sets cvalues.
#    1146 # Force an autoscale immediately because self.to_rgba() calls
#    1147 # autoscale_None() internally with the data passed to it,
#    1148 # so if vmin/vmax are not set yet, this would override them with
#    1149 # content from *cvalues* rather than levels like we want
# -> 1150 self.norm.autoscale_None(self.levels)
#    1151 self.set_array(self.cvalues)
#    1152 self.update_scalarmappable()
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\colors.py:1408, in Normalize.autoscale_None(self, A)
#    1405         A = A.data
#    1407 if self.vmin is None and A.size:
# -> 1408     self.vmin = A.min()
#    1409 if self.vmax is None and A.size:
#    1410     self.vmax = A.max()
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\colors.py:1264, in Normalize.vmin(self, value)
#    1262 if value != self._vmin:
#    1263     self._vmin = value
# -> 1264     self._changed()
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\colors.py:1292, in Normalize._changed(self)
#    1287 def _changed(self):
#    1288     """
#    1289     Call this whenever the norm is changed to notify all the
#    1290     callback listeners to the 'changed' signal.
#    1291     """
# -> 1292     self.callbacks.process('changed')
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\contour.py:1150, in ContourSet.changed(self)
#    1145     self._process_colors()  # Sets cvalues.
#    1146 # Force an autoscale immediately because self.to_rgba() calls
#    1147 # autoscale_None() internally with the data passed to it,
#    1148 # so if vmin/vmax are not set yet, this would override them with
#    1149 # content from *cvalues* rather than levels like we want
# -> 1150 self.norm.autoscale_None(self.levels)
#    1151 self.set_array(self.cvalues)
#    1152 self.update_scalarmappable()
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\colors.py:1410, in Normalize.autoscale_None(self, A)
#    1408     self.vmin = A.min()
#    1409 if self.vmax is None and A.size:
# -> 1410     self.vmax = A.max()
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\colors.py:1275, in Normalize.vmax(self, value)
#    1273 if value != self._vmax:
#    1274     self._vmax = value
# -> 1275     self._changed()
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\colors.py:1292, in Normalize._changed(self)
#    1287 def _changed(self):
#    1288     """
#    1289     Call this whenever the norm is changed to notify all the
#    1290     callback listeners to the 'changed' signal.
#    1291     """
# -> 1292     self.callbacks.process('changed')
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\contour.py:1152, in ContourSet.changed(self)
#    1150 self.norm.autoscale_None(self.levels)
#    1151 self.set_array(self.cvalues)
# -> 1152 self.update_scalarmappable()
#    1153 alphas = np.broadcast_to(self.get_alpha(), len(self.cvalues))
#    1154 for label, cv, alpha in zip(self.labelTexts, self.labelCValues, alphas):
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\collections.py:920, in Collection.update_scalarmappable(self)
#     918         # pcolormesh, scatter, maybe others flatten their _A
#     919         self._alpha = self._alpha.reshape(self._A.shape)
# --> 920     self._mapped_colors = self.to_rgba(self._A, self._alpha)
#     922 if self._face_is_mapped:
#     923     self._facecolors = self._mapped_colors
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\cm.py:509, in ScalarMappable.to_rgba(self, x, alpha, bytes, norm)
#     507 if norm:
#     508     x = self.norm(x)
# --> 509 rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     510 return rgba
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\colors.py:725, in Colormap.__call__(self, X, alpha, bytes)
#     702 r"""
#     703 Parameters
#     704 ----------
#    (...)
#     722 RGBA values with a shape of ``X.shape + (4, )``.
#     723 """
#     724 if not self._isinit:
# --> 725     self._init()
#     727 xa = np.array(X, copy=True)
#     728 if not xa.dtype.isnative:
#     729     # Native byteorder is faster.
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\colors.py:1175, in ListedColormap._init(self)
#    1173 def _init(self):
#    1174     self._lut = np.zeros((self.N + 3, 4), float)
# -> 1175     self._lut[:-3] = to_rgba_array(self.colors)
#    1176     self._isinit = True
#    1177     self._set_extremes()
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\colors.py:503, in to_rgba_array(c, alpha)
#     501         rgba = np.array(c)
#     502     else:
# --> 503         rgba = np.array([to_rgba(cc) for cc in c])
#     504 else:
#     505     rgba = np.array([to_rgba(cc) for cc in c])
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\colors.py:503, in <listcomp>(.0)
#     501         rgba = np.array(c)
#     502     else:
# --> 503         rgba = np.array([to_rgba(cc) for cc in c])
#     504 else:
#     505     rgba = np.array([to_rgba(cc) for cc in c])
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\colors.py:302, in to_rgba(c, alpha)
#     300     rgba = None
#     301 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 302     rgba = _to_rgba_no_colorcycle(c, alpha)
#     303     try:
#     304         _colors_full_map.cache[c, alpha] = rgba
#
# File c:\Users\jocyl\anaconda3\envs\comphys\Lib\site-packages\matplotlib\colors.py:384, in _to_rgba_no_colorcycle(c, alpha)
#     380             raise ValueError(
#     381                 f"Invalid string grayscale value {orig_c!r}. "
#     382                 f"Value must be within 0-1 range")
#     383         return c, c, c, alpha if alpha is not None else 1.
# --> 384     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     385 # turn 2-D array into 1-D array
#     386 if isinstance(c, np.ndarray):
#
# ValueError: Invalid RGBA argument: 'Reds'

# %% [markdown]
# Calculate the gravitational field

# %%
phi =np.gradient(u)

# %%
plt.imshow(phi[0]) # x derivative

# %%
plt.imshow(phi[1]) # y derivative

# %%
b = np.array([0,0,0,0,1,0,0,0,0])
u = solve_laplace(b,3, period=False)
plt.imshow(u.T,origin="lower")
plt.colorbar()
