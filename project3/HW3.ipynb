# %%
import numpy as np
from numba import jit, njit, prange
import matplotlib.pyplot as plt
from scipy.sparse import dia_matrix, dia_array
from mylinalg import solveLowerTriangular, solveUpperTriangular, lu, lu_solve
import time
from scipy.optimize import curve_fit

# %%
@njit(parallel=True)
def loop_kernel(N,A,d,o,z,period):
    for i in prange(N):
        for j in prange(N):
            if (i==j):
                submatrix = d
            elif (abs(i-j)==1):
                submatrix = o
            else:
                submatrix = z

            for ii in prange(N):
                for jj in prange(N):
                    A[i*N+ii,j*N+jj] = submatrix[ii,jj]

    if period:
        for k in prange(N**2):
            i = k % N; j = k // N
            if i == 0:
                A[k,(j+1)*N-1] = -1.
            if i == (N-1):
                A[k,j*N] = -1.
            if j == 0:
                A[k,N*(N-1)+i] = -1.
            if j == (N-1):
                A[k,i] = -1.

    return A

def generate_the_laplace_matrix_with_size(N=4, period=False):
    """
    assume sqrt(N) is an integer.
    period: -1 <-> N-1, 0 <-> N
    """
    nsq = N*N
    A   = np.zeros((nsq,nsq))
    
    def init_1_4_matrix(n):
        ex = np.ones(n)
        data = np.array([-ex, 4 * ex, -ex])
        offsets = np.array([-1, 0, 1])
        return dia_matrix((data, offsets), shape=(n, n)).toarray()

    def init_one_matrix(n):
        return -np.identity(n)

    def init_zero_matrix(n):
        return np.zeros((n,n))
    
    d_matrix = init_1_4_matrix(N)
    o_matrix = init_one_matrix(N)
    z_matrix = init_zero_matrix(N)
    
    A = loop_kernel(N,A,d_matrix,o_matrix,z_matrix, period)
    return A

def generate_the_rhs_vector_with_size(N=4):
    b = np.zeros(N*N)
    b[-N:] = 1
    return b

def convert_solution(x):
    usize = np.sqrt(len(x))
    u = x.reshape(int(usize),int(usize)).transpose()
    return u

def convert_vector(A):
    usize = A.shape[0]**2
    b = A.reshape(int(usize),1).transpose()[0,:]
    return b

def solve_laplace(b, N=16, period=False):
    A = generate_the_laplace_matrix_with_size(N=N, period=period)
    #x = linalg.solve(A,b) # use scipy
    x = lu_solve(A,b)      # use our solver
    u = convert_solution(x)
    return u

# %% [markdown]
# # problem 1

# %%
b = np.array([0,0,0,0,-1,0,0,0,0])
u = solve_laplace(b,3, period=False)
plt.imshow(u.T,origin="lower")
plt.title("Potential")
plt.colorbar()

# %% [markdown]
# # problem 2

# %%
N = 128
lim = 5
dx = lim*2/N
x = np.linspace(-lim, lim, N+1)
x = (x[:-1]+x[1:])/2
X,Y = np.meshgrid(x,x)
r1 = (X+1.5)**2 + Y**2
r2 = (X-1.5)**2 + Y**2
rho = np.exp(-1.25*r1**2)+1.5*np.exp(-r2**2)


plt.figure(1)
fig, ax = plt.subplots()
contourf = ax.contourf(X, Y, rho, levels=30)
contour = ax.contour(X, Y, rho, levels=6, linewidths=0.5, colors='w')
# 添加 colorbar 只对 contour
cbar = fig.colorbar(contourf, ax=ax)
cbar.set_label('Contour Levels')
plt.axis("square")
plt.tight_layout()
plt.title("source", fontsize=18)
# Out:
# Text(0.5, 1.0, 'source')

# %%
from scipy.linalg import lu_factor, lu_solve
# use my solvor is too slow... the previous problem uses my solver.

# %%
#potential = solve_laplace(source, N, period=True)
source = -convert_vector(rho*dx**2)
lu, piv = lu_factor(generate_the_laplace_matrix_with_size(128,True))
potential = lu_solve((lu,piv), source)
potential = convert_solution(potential)

# %%
plt.figure(2)
fig, ax = plt.subplots()
contourf = ax.contourf(X, Y, (potential).T, levels=30)
contour = ax.contour(X, Y, (potential).T, levels=6, linewidths=0.5, colors='w')
cbar = fig.colorbar(contourf, ax=ax)
cbar.set_label('Contour Levels')
plt.axis("square")
plt.tight_layout()
plt.title("potential", fontsize=18)
# Out:
# Text(0.5, 1.0, 'potential')

# %%
def generate_mesh(nx, ny, buff=1, 
                  xmin=0.0, xmax=1.0, ymin=0.0, ymax=1.0, period=False):
    """
    Generate 2D mesh grids for solving Laplace equation.

    nx : int
        Number of grid points in x direction.
    ny : int
        Number of grid points in y direction.
    buff : int
        Number of ghost cells around the domain.

    Returns
    
    u : 2D numpy array
        Initial guess. 
    x : 2D numpy array
        Mesh grid for x.
    y : 2D numpy array
        Mesh grid for y.
    """
    u = np.ones((nx+2*buff, ny+2*buff))
    if period:
        dx = (xmax-xmin)/(nx+2*(buff-1))
        dy = (ymax-ymin)/(ny+2*(buff-1))
        x = np.linspace(xmin-dx/2, xmax+dx/2, nx+2*buff)
        y = np.linspace(ymin-dy/2, ymax+dy/2, ny+2*buff)

    else:
        x = np.linspace(xmin, xmax, nx+2*buff)
        y = np.linspace(ymin, ymax, ny+2*buff)
        dx = x[1] - x[0]
        dy = y[1] - y[0]
    return u, x, y, dx, dy

def background(x,y):
    X,Y = np.meshgrid(y,x)
    r1 = (X+1.5)**2 + Y**2
    r2 = (X-1.5)**2 + Y**2
    rho = np.exp(-1.25*r1**2)+1.5*np.exp(-r2**2)
    return rho

# %%
@njit(parallel=True)
def jacobi(u, source, dx, uold, nx, ny):
    for j in prange(1, ny-1):
        for i in prange(1, nx-1):
            u[i,j] = 0.25*(uold[i-1,j] + uold[i+1,j] + uold[i,j-1] + uold[i,j+1] - (dx**2)*source[i,j])
    return u

@njit(parallel=True)
def gauss_seidel(u, source, dx, nx, ny):
    for j in prange(1, ny-1):
        for i in prange(1, nx-1):
            # first and second term are new.
            u[i,j] = 0.25*(u[i-1,j] + u[i,j-1] + u[i+1,j] + u[i,j+1] - (dx**2)*source[i,j])
    return u

@njit(parallel=True)
def successive_over_relax(u, source, dx, uold, nx, ny, w):
    for j in prange(1, ny+-1):
        for i in prange(1, nx-1):
            # first and second term are new.
            u[i,j] = 0.25*(u[i-1,j] + u[i,j-1] + u[i+1,j] + u[i,j+1] - (dx**2)*source[i,j])
    u = (1-w)*uold+w*u
    return u

@njit()
def update_bc(u):
    u[0,:] = u[-2,:] # left boundary
    u[-1,:] = u[1,:] # right boundary
    u[:,0] = u[:,-2] # bottom boundary
    u[:,-1] = u[:,1] # top boundary
    return u

@njit(parallel=True)
def relax(u, source, tolerance, maxiter=1e6, w=1.2, method="Jacobi"):
    """
    Relax the solution using Jacobi method.

    Parameters
    ----------
    u : 2D numpy array
        Initial guess.
    tolerance : float
        Tolerance for convergence.
    maxiter : int
        Maximum number of iterations.
    w: float
        Used in SOR method.
    method: str
        "Jacobi", "GS", "SOR".
    """
    nx, ny = u.shape # inculde ghost cells
    u = update_bc(u)

    errors = []
    iterations = []

    for n in range(maxiter):
        uold = u.copy()
        if method == "Jacobi":
            u = jacobi(u, source, dx, uold, nx, ny)
        elif method == "GS":
            u = gauss_seidel(u, source, dx, nx, ny)
        elif method == "SOR":
            u = successive_over_relax(u, source, dx, uold, nx, ny, w)
        err = 0
        for i in prange(1,nx-1):
            for j in prange(1,ny-1):
                u1 = u[i,j]
                u2 = uold[i,j]
                err0 = (u1 - u2)**2
                err += err0

        err = np.sqrt(err)/nx/ny
        errors.append(err)
        iterations.append(n)
        if err < tolerance:
            print("err:", err, n, "end!")
            break
        
    return u, iterations, errors

# %%
n = 128
u, x, y, dx, dy = generate_mesh(n, n, xmin=-5, xmax=5, ymin=-5, ymax=5, period=True)
rho = background(x,y)
u, itt_jacobi, err_jacobi = relax(u, rho, tolerance=1e-9, maxiter=200000, method="Jacobi")

u, x, y, dx, dy = generate_mesh(n, n, xmin=-5, xmax=5, ymin=-5, ymax=5, period=True)
u, itt_gs, err_gs = relax(u, rho, tolerance=1e-9, maxiter=200000, method="GS")
u, x, y, dx, dy = generate_mesh(n, n, xmin=-5, xmax=5, ymin=-5, ymax=5, period=True)
u, itt_sor_1, err_sor_1 = relax(u, rho, tolerance=1e-9, w=1.2, maxiter=200000, method="SOR")
u, x, y, dx, dy = generate_mesh(n, n, xmin=-5, xmax=5, ymin=-5, ymax=5, period=True)
u, itt_sor_2, err_sor_2 = relax(u, rho, tolerance=1e-9, w=1.5, maxiter=200000, method="SOR")
# Out:
# err: 9.997750891877464e-10 33601 end!
# err: 9.999707770639408e-10 17989 end!
# err: 9.999882469246172e-10 15236 end!
# err: 9.99647110810521e-10 12440 end!

# %%
u, x, y, dx, dy = generate_mesh(n, n, xmin=-5, xmax=5, ymin=-5, ymax=5, period=True)
u, itt_sor_3, err_sor_3 = relax(u, rho, tolerance=1e-9, w=2.0, maxiter=200000, method="SOR")

# %%
plt.figure()
plt.plot(itt_jacobi, err_jacobi, label = "jacobi")
plt.plot(itt_gs, err_gs, label = "GS")
plt.plot(itt_sor_1, err_sor_1, label = "SOR, w=1.2")
plt.plot(itt_sor_2, err_sor_2, label = "SOR, w=1.5")
#plt.plot(itt_sor_3, err_sor_3, label = "SOR, w=2.0")
plt.yscale("log")
plt.xlabel("iterations", fontsize = 18)
plt.ylabel("error", fontsize = 18)
plt.legend()
plt.grid()
plt.tight_layout()

# %%
ns = [32,64,128]
t_jacobi = []
t_gs = []
t_sor_1 = []
t_sor_2 = []
for n in ns:
    u, x, y, dx, dy = generate_mesh(n, n, xmin=-5, xmax=5, ymin=-5, ymax=5, period=True)
    rho = background(x,y)
    t0 = time.time()
    u, itt_jacobi, err_jacobi = relax(u, rho, tolerance=1e-7, maxiter=1000000, method="Jacobi")
    t1 = time.time()
    t_jacobi.append(len(itt_jacobi))

    u, x, y, dx, dy = generate_mesh(n, n, xmin=-5, xmax=5, ymin=-5, ymax=5, period=True)
    t0 = time.time()
    u, itt_gs, err_gs = relax(u, rho, tolerance=1e-7, maxiter=1000000, method="GS")
    t1 = time.time()
    t_gs.append(len(itt_gs))

    u, x, y, dx, dy = generate_mesh(n, n, xmin=-5, xmax=5, ymin=-5, ymax=5, period=True)
    t0 = time.time()
    u, itt_sor_1, err_sor_1 = relax(u, rho, tolerance=1e-7, w=1.2, maxiter=1000000, method="SOR")
    t1 = time.time()
    t_sor_1.append(len(itt_sor_1))

    u, x, y, dx, dy = generate_mesh(n, n, xmin=-5, xmax=5, ymin=-5, ymax=5, period=True)
    t0 = time.time()
    u, itt_sor_2, err_sor_2 = relax(u, rho, tolerance=1e-7, w=1.5, maxiter=1000000, method="SOR")
    t1 = time.time()
    t_sor_2.append(len(itt_sor_2))
# Out:
# err: 9.997201356033835e-08 1463 end!
# err: 9.96460054069327e-08 809 end!
# err: 9.997486464616552e-08 690 end!
# err: 9.939830232106332e-08 568 end!
# err: 9.993503451330277e-08 5150 end!
# err: 9.992711994367472e-08 2873 end!
# err: 9.981693691097028e-08 2459 end!
# err: 9.986247181896291e-08 2030 end!
# err: 9.998079679203412e-08 18073 end!
# err: 9.990145218015807e-08 10216 end!
# err: 9.999465928037807e-08 8763 end!
# err: 9.991901131405473e-08 7260 end!

# %%
plt.figure()
plt.loglog(ns, t_jacobi, label = "Jacobi")
plt.loglog(ns, t_gs, label = "GS")
plt.loglog(ns, t_sor_1, label = "SOR, w=1.2")
plt.loglog(ns, t_sor_2, label = "SOR, w=1.5")

plt.xlabel("resolution n", fontsize = 18)
plt.ylabel("iteration", fontsize = 18)
plt.legend()
plt.grid(True, which='minor')
plt.tight_layout()

# %%
def func(xdata, A, B):
    return A*xdata+B
popt, pcov = curve_fit(func, itt_gs[-1000:], np.log(np.array(err_gs[-1000:])))
print(popt[0])
# Out:
# -0.0005927231017372823
